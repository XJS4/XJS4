# %% [markdown]
# # pearOS Github Links
#
# 1. Pear Project Default Link
#
# https://github.com/Pear-Project
#
# 2. Default Kvantum Themes for pearOS
#
# https://github.com/Pear-Project/pearOS-Default-Kvantum
#
# 3. Default Window Decorations for pearOS NiceC0re
#
# https://github.com/Pear-Project/pearOS-Default-Aurorae
#
# 4. Default GTK theme for pearOS
#
# https://github.com/Pear-Project/pearOS-Default-GTK-Theme
#
# 5. pearOS Icon Repository for NiceC0re
#
# https://github.com/Pear-Project/pearOS-Default-Icons
#
# 6. pearOS SDDM Repository
#
# https://github.com/Pear-Project/pearOS-Default-SDDM
#
# 7. pearOS NiceC0re Default Wallpapers (Not the default, but the defaults)
#
# https://github.com/Pear-Project/pearOS-Default-Wallpapers
#
# 8. Packup (pearOS backup tool)
#
# https://github.com/Pear-Project/packup
#
# 9. Piri Assistant
#
# https://github.com/Pear-Project/Piri-Vocal-Assistant-Linux
#
# 10. pearID Desktop (Yet unfinished I believe)
#
# https://github.com/Pear-Project/pearID-desktop
#
# 11. pearOS NiceC0re default .zshrc
#
# https://github.com/Pear-Project/pearOS-Default-ZSHrc
#
# 12. pearOS version of the Kpple Menu
#
# https://github.com/Pear-Project/pearOS-Default-Menu
#
# 13. pearOS Theme Switcher Application
#
# https://github.com/Pear-Project/theme-switcher
#
# 14. pearOS Touchpad config
#
# https://github.com/Pear-Project/pearOS-Default-Touchpad-Config
#
# 15. pearOS neofetch fork
#
# https://github.com/Pear-Project/neofetch
#
# 16. pearOS Juno Theme
#
# https://github.com/Pear-Project/Juno
#
# 17. pearOS Launchpad
#
# https://github.com/Pear-Project/pearOS-Default-Launchpad
#
# 18. pearOS update checker
#
# https://github.com/Pear-Project/update-mgr
#
# 19. pearOS System Overview (macOS Style)
#
# https://github.com/Pear-Project/system-overview
#
# 20. pearOS Grub Theme
#
# https://github.com/Pear-Project/pearOS-Default-GRUB
#
# 21. pearOS Control Centre (Based off of the macOS Big Sur control centre)
#
# https://github.com/Pear-Project/Control-Centre
#
# 22. PairDrop (AirDrop but for Andriod)
#
# https://github.com/Pear-Project/pairdrop-android
#
# 23. USB Utility (Disk Utility but pearOS)
#
# https://github.com/Pear-Project/USBUtility
#
# 24. PEXT Installer
#
# https://github.com/Pear-Project/pext-installer
#
# 25. **pearOS Boot Sound Github Page (Very Useful)**
#
# https://github.com/Pear-Project/pearos-boot-sound
#
# 26. pearOS Default Font
#
# https://github.com/Pear-Project/pearOS-Default-font
